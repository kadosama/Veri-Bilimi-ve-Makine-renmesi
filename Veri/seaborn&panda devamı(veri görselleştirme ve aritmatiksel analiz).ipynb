# %% [markdown]
# # VERİ SETİNİN YAPISAL ANALİZİ VE HİKAYESİ

# %%
import seaborn as sns
planets=sns.load_dataset("planets")
planets.head()
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %%
#BU NASASININ GALAKSİLERLE İLGİLİ Bİ TABLOSU(HİKAYESİ NASIL OLUŞTUĞU FLN)

# %%
df=planets.copy()

# %%
df.head()
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %%
df.tail()
# Out:
#        method  number  orbital_period  mass  distance  year
# 1030  Transit       1        3.941507   NaN     172.0  2006
# 1031  Transit       1        2.615864   NaN     148.0  2007
# 1032  Transit       1        3.191524   NaN     174.0  2007
# 1033  Transit       1        4.125083   NaN     293.0  2008
# 1034  Transit       1        4.187757   NaN     260.0  2008

# %%
df.info()#yapısal analiz
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1035 entries, 0 to 1034
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   method          1035 non-null   object
#  1   number          1035 non-null   int64
#  2   orbital_period  992 non-null    float64
#  3   mass            513 non-null    float64
#  4   distance        808 non-null    float64
#  5   year            1035 non-null   int64
# dtypes: float64(3), int64(2), object(1)
# memory usage: 48.6+ KB

# %%
#object: kategorisel değişen olmalıdır (sayısal açıdan pek kullanmıyacağmız kategorik değişkenler örn
#cinsiyet,1 mi 2 mi olduğu  fln)
#değilse çevirmek önerilir

# %%
df.dtypes
# Out:
# method             object
# number              int64
# orbital_period    float64
# mass              float64
# distance          float64
# year                int64
# dtype: object

# %%
import pandas as pd
df.method=pd.Categorical(df.method)

# %%
df.dtypes
# Out:
# method            category
# number               int64
# orbital_period     float64
# mass               float64
# distance           float64
# year                 int64
# dtype: object

# %%
df.head()
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %% [markdown]
# # VERİ SETİNİN BETİMLENMESİ

# %%
df.head()
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %%
df.shape
# Out:
# (1035, 6)

# %%
df.columns
# Out:
# Index(['method', 'number', 'orbital_period', 'mass', 'distance', 'year'], dtype='object')

# %%
df.describe().T
# Out:
#                  count         mean           std          min         25%  \
# number          1035.0     1.785507      1.240976     1.000000     1.00000
# orbital_period   992.0  2002.917596  26014.728304     0.090706     5.44254
# mass             513.0     2.638161      3.818617     0.003600     0.22900
# distance         808.0   264.069282    733.116493     1.350000    32.56000
# year            1035.0  2009.070531      3.972567  1989.000000  2007.00000
#
#                       50%       75%       max
# number             1.0000     2.000       7.0
# orbital_period    39.9795   526.005  730000.0
# mass               1.2600     3.040      25.0
# distance          55.2500   178.500    8500.0
# year            2010.0000  2012.000    2014.0

# %%
df.describe(include="all").T
# Out:
#                  count unique              top freq         mean  \
# method            1035     10  Radial Velocity  553          NaN
# number          1035.0    NaN              NaN  NaN     1.785507
# orbital_period   992.0    NaN              NaN  NaN  2002.917596
# mass             513.0    NaN              NaN  NaN     2.638161
# distance         808.0    NaN              NaN  NaN   264.069282
# year            1035.0    NaN              NaN  NaN  2009.070531
#
#                          std       min      25%      50%      75%       max
# method                   NaN       NaN      NaN      NaN      NaN       NaN
# number              1.240976       1.0      1.0      1.0      2.0       7.0
# orbital_period  26014.728304  0.090706  5.44254  39.9795  526.005  730000.0
# mass                3.818617    0.0036    0.229     1.26     3.04      25.0
# distance          733.116493      1.35    32.56    55.25    178.5    8500.0
# ...

# %% [markdown]
# # Eksik Değerlerin İncelenmesi

# %%
df.head()
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %%
#hiç eksik gözlem(Değer) varmı?
df.isnull().values.any()
# Out:
# True

# %%
#hangi değişkende kaçar tane var
df.isnull().sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of       method  number  orbital_period   mass  distance   year
# 0      False   False           False  False     False  False
# 1      False   False           False  False     False  False
# 2      False   False           False  False     False  False
# 3      False   False           False  False     False  False
# 4      False   False           False  False     False  False
# ...      ...     ...             ...    ...       ...    ...
# 1030   False   False           False   True     False  False
# 1031   False   False           False   True     False  False
# 1032   False   False           False   True     False  False
# 1033   False   False           False   True     False  False
# 1034   False   False           False   True     False  False
#
# [1035 rows x 6 columns]>

# %%
#eksik değerlere 0 koyma
#df["degisken(column)"].fillna(0,inplace=True)

# %%
df["orbital_period"].fillna(0,inplace=True)

# %%
df["orbital_period"].fillna(df.orbital_period.mean(),inplace=True)

# %%
df.fillna(df.mean(),inplace=True)

# %% [markdown]
# # KATEGORİK DEĞİŞKEN ÖZELLİKLERİ

# %%
import seaborn as sns
planets=sns.load_dataset("planets")
planets.head()
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %%
df=planets.copy()

# %%
kat_df=df.select_dtypes(include=["object"])

# %%
kat_df.head()
# Out:
#             method
# 0  Radial Velocity
# 1  Radial Velocity
# 2  Radial Velocity
# 3  Radial Velocity
# 4  Radial Velocity

# %%
kat_df.method.unique()#methodların ne olduğu listeler
# Out:
# array(['Radial Velocity', 'Imaging', 'Eclipse Timing Variations',
#        'Transit', 'Astrometry', 'Transit Timing Variations',
#        'Orbital Brightness Modulation', 'Microlensing', 'Pulsar Timing',
#        'Pulsation Timing Variations'], dtype=object)

# %%
kat_df["method"].value_counts().count()#kaç method çeşidi var
# Out:
# 10

# %%
#.nuniqiue() fonk u da kaç çeşit olduğunu söler

# %%
kat_df.value_counts()#methodlardan kaçar tane var
# Out:
# method
# Radial Velocity                  553
# Transit                          397
# Imaging                           38
# Microlensing                      23
# Eclipse Timing Variations          9
# Pulsar Timing                      5
# Transit Timing Variations          4
# Orbital Brightness Modulation      3
# Astrometry                         2
# Pulsation Timing Variations        1
# dtype: int64

# %%
kat_df["method"].value_counts()
# Out:
# Radial Velocity                  553
# Transit                          397
# Imaging                           38
# Microlensing                      23
# Eclipse Timing Variations          9
# Pulsar Timing                      5
# Transit Timing Variations          4
# Orbital Brightness Modulation      3
# Astrometry                         2
# Pulsation Timing Variations        1
# Name: method, dtype: int64

# %%
df["method"].value_counts().plot.bar()#normal bilindik grafik
# Out:
# <AxesSubplot:>

# %%
df["method"].value_counts().plot.barh(); #normal bilindik grafik transpose hali ; atınca üstteki yazı 
#gidiyo

# %% [markdown]
# # SÜREKLİ DEĞİŞKEN ÖZETLERİ

# %%
df=df.select_dtypes(include=["float64","int64"])

# %%
df.head()
# Out:
#    number  orbital_period   mass  distance  year
# 0       1         269.300   7.10     77.40  2006
# 1       1         874.774   2.21     56.95  2008
# 2       1         763.000   2.60     19.84  2011
# 3       1         326.030  19.40    110.62  2007
# 4       1         516.220  10.50    119.47  2009

# %%
df.describe().T
# Out:
#                  count         mean           std          min         25%  \
# number          1035.0     1.785507      1.240976     1.000000     1.00000
# orbital_period   992.0  2002.917596  26014.728304     0.090706     5.44254
# mass             513.0     2.638161      3.818617     0.003600     0.22900
# distance         808.0   264.069282    733.116493     1.350000    32.56000
# year            1035.0  2009.070531      3.972567  1989.000000  2007.00000
#
#                       50%       75%       max
# number             1.0000     2.000       7.0
# orbital_period    39.9795   526.005  730000.0
# mass               1.2600     3.040      25.0
# distance          55.2500   178.500    8500.0
# year            2010.0000  2012.000    2014.0

# %%
df["distance"].describe().T
# Out:
# count     808.000000
# mean      264.069282
# std       733.116493
# min         1.350000
# 25%        32.560000
# 50%        55.250000
# 75%       178.500000
# max      8500.000000
# Name: distance, dtype: float64

# %% [markdown]
# # dağılım grafikler
# barplot

# %%
diamonds=sns.load_dataset("diamonds")
df=diamonds.copy()
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20889 entries, 0 to 20888
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    20889 non-null  float64
#  1   cut      20889 non-null  category
#  2   color    20889 non-null  category
#  3   clarity  20889 non-null  category
#  4   depth    20889 non-null  float64
#  5   table    20889 non-null  float64
#  6   price    20889 non-null  int64
#  7   x        20889 non-null  float64
#  8   y        20889 non-null  float64
#  9   z        20889 non-null  float64
# dtypes: category(3), float64(6), int64(1)
# memory usage: 1.2 MB

# %%
df.describe().T
# Out:
#          count         mean          std    min      25%      50%      75%  \
# carat  20889.0     0.969642     0.309144    0.2     0.83     1.01     1.12
# depth  20889.0    61.825262     1.550319   43.0    61.10    61.90    62.70
# table  20889.0    57.766174     2.224428   43.0    56.00    58.00    59.00
# price  20889.0  4665.999904  2095.749201  326.0  3403.00  4564.00  6066.00
# x      20889.0     6.248325     0.780820    0.0     6.02     6.41     6.69
# y      20889.0     6.247664     0.769308    0.0     6.02     6.41     6.68
# z      20889.0     3.860994     0.488580    0.0     3.72     3.97     4.12
#
#            max
# carat     3.01
# depth    71.80
# table    70.00
# price  9108.00
# x         9.23
# y         9.10
# z         5.97

# %%
df["cut"].value_counts()
# Out:
# Ideal        6791
# Premium      5773
# Very Good    5131
# Good         2361
# Fair          833
# Name: cut, dtype: int64

# %%
df["color"].value_counts()
# Out:
# G    4168
# H    3803
# F    3588
# E    3232
# D    2388
# I    2313
# J    1397
# Name: color, dtype: int64

# %%
#ordinal tanımlama
from pandas.api.types import CategoricalDtype

# %%
df.cut.head()
# Out:
# 0      Ideal
# 1    Premium
# 2       Good
# 3    Premium
# 4       Good
# Name: cut, dtype: category
# Categories (5, object): ['Ideal', 'Premium', 'Very Good', 'Good', 'Fair']

# %%
df.cut=df.cut.astype(CategoricalDtype(ordered=True))

# %%
df.dtypes
# Out:
# carat       float64
# cut        category
# color      category
# clarity    category
# depth       float64
# table       float64
# price         int64
# x           float64
# y           float64
# z           float64
# dtype: object

# %%
df.cut.head(1)
# Out:
# 0    Ideal
# Name: cut, dtype: category
# Categories (5, object): ['Ideal' < 'Premium' < 'Very Good' < 'Good' < 'Fair']

# %%
cut_kategoriler=["Fair","good","very good","premium","ideal"]

# %%
df.cut=df.cut.astype(CategoricalDtype(categories=cut_kategoriler ,ordered=True))

# %%
df.cut.head(1)
# Out:
# 0    NaN
# Name: cut, dtype: category
# Categories (5, object): ['Fair' < 'good' < 'very good' < 'premium' < 'ideal']

# %%
#barplot

# %%
df["cut"].value_counts().plot.barh().set_title("cut degişekenin sınıf frekansları");

# %%
(df["cut"]
.value_counts()
.plot.barh()
.set_title("cut degişekenin sınıf frekansları"));

# %%
sns.barplot(x="cut",y=df.cut.index,data=df);

# %% [markdown]
# # sütün grafik çaprazlamalar

# %%
df.head()
# Out:
#    carat  cut color clarity  depth  table  price     x     y     z
# 0   0.23  NaN     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  NaN     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23  NaN     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  NaN     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31  NaN     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
sns.catplot(x="cut",y="price",data=df);

# %%
sns.barplot(x="cut",y="price",hue="color",data=df);#çizgiler std

# %%
df.groupby(["cut","color"])["price"].mean()#doğrulama
# Out:
# cut        color
# Fair       D        4479.043956
#            E        4383.870690
#            F        4516.211180
#            G        4720.822695
#            H        4785.857988
#            I        4731.314607
#            J        4538.045455
# good       D                NaN
#            E                NaN
#            F                NaN
#            G                NaN
#            H                NaN
#            I                NaN
#            J                NaN
# very good  D                NaN
#            E                NaN
#            F                NaN
#            G                NaN
#            H                NaN
#            I                NaN
#            J                NaN
# premium    D                NaN
#            E                NaN
#            F                NaN
#            G                NaN
#            H                NaN
#            I                NaN
#            J                NaN
# ...

# %% [markdown]
# # Histogram ve Yoğunluk Grafiğinin Oluşturulması

# %%
import seaborn as sns
diamonds=sns.load_dataset("diamonds")
df=diamonds.copy()
df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 20884   1.29  Very Good     G     VS1   62.3   58.0   9105  6.98  7.01  4.36
# 20885   1.62    Premium     F     SI2   61.6   60.0   9106  7.52  7.55  4.64
# 20886   1.21    Premium     F     VS1   61.6   59.0   9107  6.84  6.77  4.19
# 20887   1.51  Very Good     H     SI2   62.3   58.0   9107  7.31  7.35  4.57
# 20888   1.52    Premium     I     VS2   62.6   59.0   9108  7.34  7.19  4.50
#
# [20889 rows x 10 columns]

# %%
sns.displot(df.price,kde=False);

# %%
# ?sns.displot#orjinal argümanlarları gösterir ayrıca(kde=yoğunluk hist=histogram)
# Out:
# Object `sns.displot#orjinal argümanlarları gösterir ayrıca(kde=yoğunluk hist=histogram)` not found.

# %%
sns.displot(df.price,bins=10,kde=False);

# %%
sns.displot(df.price,bins=1000,kde=False);#kutular küçüldü(aralıklar)(kutular arttı)(ölçüm hassaslaştıda denebilir)

# %%
sns.displot(df.price,kde=True);

# %%
sns.displot(df.price,hist=False,kde=True);#sadece çizgili grafiği koyar(yoğunluk grafiği)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-133-af42d4e2b696> in <module>
# ----> 1 sns.displot(df.price,hist=False,kde=True);#sadece çizgili grafiği koyar(yoğunluk grafiği)
#
# ~\anaconda3\lib\site-packages\seaborn\distributions.py in displot(data, x, y, hue, row, col, weights, kind, rug, rug_kws, log_scale, legend, palette, hue_order, hue_norm, color, col_wrap, row_order, col_order, height, aspect, facet_kws, **kwargs)
#    2225
#    2226             _assign_default_kwargs(hist_kws, p.plot_univariate_histogram, histplot)
# -> 2227             p.plot_univariate_histogram(**hist_kws)
#    2228
#    2229         else:
#
# ~\anaconda3\lib\site-packages\seaborn\distributions.py in plot_univariate_histogram(self, multiple, element, fill, common_norm, common_bins, shrink, kde, kde_kws, color, legend, line_kws, estimate_kws, **plot_kws)
# ...

# %%
sns.kdeplot(df.price,shade=True);

# %% [markdown]
# # Histogram ve Yoğunluk Çaprazlamalar

# %%
(sns
 .FacetGrid(df,#kategorileri boyutlara ayırmak için
           hue="cut",#boyut (renk tonu)
           height=5,
           xlim=(0,10000))#x ekseni
 .map(sns.kdeplot,"price",shade=True)#price cinsinden bi üstüdeki grafik gibi olan grafikten yararlandık
 .add_legend()#kategoriler hangi renk 
);

# %%
sns.catplot(x="cut",y="price",hue="color",kind="point",data=df);

# %%
#genelde datalarda verilen bilgilerden farklı değerler olur graphda çünkü bunlar grapaha gitmeden önce agreege edilir yani toplulaştırmaşta işlemi yaplır(örn:count max mn last first median sum std mean gibi....)

# %%
import seaborn as sns
tips=sns.load_dataset("tips")
df=tips.copy()
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df["sex"].value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
df["smoker"].value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
df["smoker"].unique()
# Out:
# ['No', 'Yes']
# Categories (2, object): ['No', 'Yes']

# %%
df["sex"].value_counts().count()
# Out:
# 2

# %%
df["smoker"].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
df["smoker"].value_counts().plot.barh();

# %% [markdown]
# # BOX PLOT(KUTU GRAFİĞİ)

# %%
sns.boxplot(x=df["total_bill"]);#sol min sağ max ötesindekiler aykırı değerler
#boyalının sağı sıralı değerler ortası medyan sağ yüzde 25 sol yüzde 75 mesela

# %%
sns.boxplot(x=df["total_bill"],orient="v");#grafiği yatay yapar (vertical)
# Out:
# C:\Users\kadosama\anaconda3\lib\site-packages\seaborn\_core.py:1319: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))

# %%
#hangi günler daa çok kazanıoz?

# %%
sns.boxplot(x="day",y="total_bill",data=df);#aykırı değerler , medyan ,ortalama da alınır

# %%
#sabahmı akşamı daa fazla kazanıoz

# %%
sns.boxplot(x="time",y="total_bill",data=df);

# %%
#kişi sayısı kazanç ilişkisi

# %%
sns.boxplot(x="size",y="total_bill",data=df);

# %%
sns.boxplot(x="day",y="total_bill",hue="sex",data=df);

# %% [markdown]
# # violin grafik

# %%
sns.catplot(y="total_bill",kind="violin",data=df);#boxplotla yoğunluk grafiği kesişimi gibi

# %%
sns.catplot(x="day",y="total_bill",kind="violin",data=df);

# %%
sns.catplot(x="day",y="total_bill",hue="sex",kind="violin",data=df);#hue=kırılım ,çaprazlama,boyut

# %% [markdown]
# # korelasyon grafikleri(2 değişkenli grafikler)

# %%
sns.scatterplot(x="total_bill",y="tip",data=df);#saçılım grafiği

# %%
sns.scatterplot(x="total_bill",y="tip",hue="time",data=df);

# %%
sns.scatterplot(x="total_bill",y="tip",hue="time",style="time",data=df);#time göre sitilini değiştirdi

# %%
sns.scatterplot(x="total_bill",y="tip",hue="day",style="time",data=df);#time göre sitilini değiştirdi

# %%
sns.scatterplot(x="total_bill",y="tip",hue="day",size="size",data=df);#size sayısal parametre eklemek için

# %%
sns.scatterplot(x="total_bill",y="tip",hue="size",size="size",data=df);

# %% [markdown]
# # doğrusal ilişkinin gösterilmesi

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.lmplot(x="total_bill",y="tip",data=df);

# %%
#noktalar sıklanınca doğruda sapma az ama diğerlerinde var

# %%
sns.lmplot(x="total_bill",y="tip",hue="smoker",data=df);

# %%
sns.lmplot(x="total_bill",y="tip",hue="smoker",col="time",data=df);

# %%
sns.lmplot(x="total_bill",y="tip",hue="smoker",col="time",row="sex",data=df);

# %%
#style ve hue ve size ve col çaprazlamalarda(boyutlarda) işimize yarar birden fazla parametre incelemesi açısından

# %% [markdown]
# # Scatter Plot Matrisi

# %%
iris=sns.load_dataset("iris")
df=iris.copy()
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.pairplot(df);

# %%
sns.pairplot(df,hue="species");

# %%
sns.pairplot(df,hue="species",markers=["o","s","d"]);#türlerin nası sırada olcağını seçebiliyon

# %%
sns.pairplot(df,kind="reg");

# %%
sns.pairplot(df,hue="species",kind="reg");

# %% [markdown]
# # ısı haritası (heat map)

# %%
flights=sns.load_dataset("flights")
df=flights.copy()
df.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
df=df.pivot("month","year","passengers");

# %%
df
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
sns.heatmap(df);#pivottable kurman lzm

# %%
sns.heatmap(df,annot=True,fmt="d");

# %%
sns.heatmap(df,annot=True,fmt="d",linewidths=.5);

# %%
sns.heatmap(df,annot=True,fmt="d",linewidths=.5,cbar=False);

# %% [markdown]
# # çizgi grafik (line plot)

# %%
fmri=sns.load_dataset("fmri")
df=fmri.copy()
df
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
#timepoint değişkeni de aslında kategorisel olabilir sayısal olmasına rağmen

# %%
df.groupby("timepoint")["signal"].count()
# Out:
# timepoint
# 0     56
# 1     56
# 2     56
# 3     56
# 4     56
# 5     56
# 6     56
# 7     56
# 8     56
# 9     56
# 10    56
# 11    56
# 12    56
# 13    56
# 14    56
# 15    56
# 16    56
# 17    56
# 18    56
# Name: signal, dtype: int64

# %%
df.groupby("signal")["timepoint"].count()
# Out:
# signal
# -0.255486    1
# -0.238474    1
# -0.224351    1
# -0.181241    1
# -0.178510    1
#             ..
#  0.455575    1
#  0.460896    1
#  0.476055    1
#  0.494787    1
#  0.564985    1
# Name: timepoint, Length: 1064, dtype: int64

# %%
df.groupby("signal").count()
# Out:
#            subject  timepoint  event  region
# signal
# -0.255486        1          1      1       1
# -0.238474        1          1      1       1
# -0.224351        1          1      1       1
# -0.181241        1          1      1       1
# -0.178510        1          1      1       1
# ...            ...        ...    ...     ...
#  0.455575        1          1      1       1
#  0.460896        1          1      1       1
#  0.476055        1          1      1       1
#  0.494787        1          1      1       1
#  0.564985        1          1      1       1
#
# [1064 rows x 4 columns]

# %%
df.groupby("timepoint")["signal"].describe()
# Out:
#            count      mean       std       min       25%       50%       75%  \
# timepoint
# 0           56.0 -0.016662  0.028326 -0.064454 -0.039169 -0.018382  0.003539
# 1           56.0 -0.025002  0.030641 -0.082174 -0.046299 -0.024533 -0.005388
# 2           56.0 -0.012873  0.035440 -0.110565 -0.034944 -0.013183  0.009318
# 3           56.0  0.034446  0.058260 -0.089708 -0.001157  0.028430  0.061840
# 4           56.0  0.098194  0.092838 -0.046347  0.030912  0.070166  0.144911
# 5           56.0  0.137725  0.123353 -0.017946  0.042762  0.096535  0.211638
# 6           56.0  0.127515  0.137332 -0.054405  0.022409  0.068850  0.218919
# 7           56.0  0.075660  0.129704 -0.108222 -0.016252  0.032486  0.144781
# 8           56.0  0.013420  0.104216 -0.181241 -0.049453 -0.012834  0.030396
# 9           56.0 -0.032041  0.072728 -0.152929 -0.075693 -0.038496  0.008717
# 10          56.0 -0.053685  0.053148 -0.176453 -0.078893 -0.052906 -0.015302
# ...

# %%
sns.lineplot(x="timepoint",y="signal",data=df);

# %%
#seaborn kütüphanesi genelde işlemleri yaplmış verileri grafiğe sokar(yukarda maviler mean açık mavi std)

# %%
sns.lineplot(x="timepoint",y="signal",hue="event",data=df);

# %%
sns.lineplot(x="timepoint",y="signal",hue="event",style="event",data=df);

# %%
sns.lineplot(x="timepoint"
             ,y="signal"
             ,hue="event"
             ,style="event",markers=True,dashes=False,data=df);#mark koyu notkalar dash kısa kısa çizgiler

# %%
sns.lineplot(x="timepoint"
             ,y="signal"
             ,hue="region"
             ,style="event",markers=True,dashes=False,data=df);

# %% [markdown]
# # Basit Zaman Serisi Grafiği Oluşturulması

# %%
# !pip install pandas_datareader 
import pandas_datareader as pr

# %%
df=pr.get_data_yahoo("AAPL",start="2016-01-01",end="2019-09-25")

# %%
df.head()
# Out:
#                  High        Low       Open      Close       Volume  Adj Close
# Date
# 2016-01-04  26.342501  25.500000  25.652500  26.337500  270597600.0  24.251438
# 2016-01-05  26.462500  25.602501  26.437500  25.677500  223164000.0  23.643711
# 2016-01-06  25.592501  24.967501  25.139999  25.174999  273829600.0  23.181007
# 2016-01-07  25.032499  24.107500  24.670000  24.112499  324377600.0  22.202669
# 2016-01-08  24.777500  24.190001  24.637501  24.240000  283192000.0  22.320072

# %%
kapanış=df["Close"]

# %%
kapanış.head()
# Out:
# Date
# 2016-01-04    26.337500
# 2016-01-05    25.677500
# 2016-01-06    25.174999
# 2016-01-07    24.112499
# 2016-01-08    24.240000
# Name: Close, dtype: float64

# %%
kapanış.plot();

# %%
kapanış.index
# Out:
# DatetimeIndex(['2016-01-04', '2016-01-05', '2016-01-06', '2016-01-07',
#                '2016-01-08', '2016-01-11', '2016-01-12', '2016-01-13',
#                '2016-01-14', '2016-01-15',
#                ...
#                '2019-09-12', '2019-09-13', '2019-09-16', '2019-09-17',
#                '2019-09-18', '2019-09-19', '2019-09-20', '2019-09-23',
#                '2019-09-24', '2019-09-25'],
#               dtype='datetime64[ns]', name='Date', length=939, freq=None)

# %%
kapanış.index=pd.DatetimeIndex(kapanış.index)

# %% [markdown]
# numinal=sayısal değişken
# ordinal=kategorisel,object değişkenler
